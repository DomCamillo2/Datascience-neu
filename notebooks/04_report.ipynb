# %% [markdown]
# # Report: Linguistic loci of annotation disagreement (Kafka DE/EN)
#
# **Authors:** Dominik Soballa, Luca Bouché
#
# Lead with linguistic loci — not a model bake-off.

# %% [markdown]
# ## Research question
#
# Which linguistic categories show the strongest automatic-annotation disagreement, and does the profile differ between the German and English corpus versions?

# %% [markdown]
# ## Methods (summary)
#
# SpaCy tokenization fixed; Ollama `llama3.2:3b` second annotator; sample 300 sentences/language; seed 42.

# %% [markdown]
# ## Results
#
# *(Fill from notebook 03 figures.)*

# %% [markdown]
# ## Limitations
#
# SpaCy/LLM are not gold; literary domain; 3B model; dual error; and the English text is a translation, so DE/EN contrasts are corpus-version differences.

# %% [markdown]
# ## Takeaway for corpus linguistics
#
# *(Which categories deserve additional caution in automatic corpus annotation?)*
